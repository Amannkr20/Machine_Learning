# %%
n=[221,545,76569,344578,3958835,9228394,456789999,23456789765432145678654323123456784321345679999]
# Return all no ending 9 using maths 

# filtered_numbers = [x for x in n if str(x)[-1] == '9'] 
filtered_numbers = [x for x in n if x % 10 == 9]
print(filtered_numbers)
# Out:
# [76569, 456789999, 23456789765432145678654323123456784321345679999]

# %%
n=[(12,["Abhi"]),(13,["Amrit",11]),(14,["ravi",43])]
print(sorted(n,key=lambda x: x[1][0][1]))
# Out:
# [(14, ['ravi', 43]), (12, ['Abhi']), (13, ['Amrit', 11])]

# %%
#sum of all digit of a numbers using loop
n=int(input("Enter a number: "))
og_n = n
sum=0
while n > 0:
    num = n % 10
    sum = sum + num
    n = n // 10

print("Sum of digits:",sum)
print("Number:",og_n)
# Out:
# Sum of digits: 14
# Number: 4334
