# %%
class Demo: 
    def __init__(self,a,b):
        self.a=a
        self.b=b
    def sums(self):
        return self.a+self.b
ob=Demo(12,6)
print(ob.sums())
# Out:
# 18

# %%
class Demo:
    def __init__(self):
        pass
    def add(self,a,b):
        print("The sum is",a+b)

# %%
class Demo:
    def __init__(jon):
        pass
    def add(self,a,b):
        print("The sum is",a+b)
obj=Demo()
obj.add(90,7)
# Out:
# The sum is 97
